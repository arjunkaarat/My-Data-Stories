# %%
import pandas as pd
import seaborn as sns, numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
#Load Institutions data
Institutions = pd.read_csv('2012_to_2014_institutions_data.csv', dtype=str)
Institutions['Assets_000_Panel'] = pd.to_numeric(Institutions['Assets_000_Panel'])

#Load Loans Data
Loans = pd.read_csv('2012_to_2014_loans_data.csv', dtype = str)
for column in ['Loan_Amount_000','Applicant_Income_000','Conforming_Limit_000','FFIEC_Median_Family_Income']:
    Loans[column] = pd.to_numeric(Loans[column], errors='coerce')

# %%
Institutions.head()
# Out:
#   As_of_Year Respondent_ID Agency_Code              Respondent_Name_TS  \
# 0       2012    0000000047           1         FIRST FINANCIAL BANK NA
# 1       2012    0000000056           1      FIRST FINANCIAL BANK, N.A.
# 2       2012    0000000086           1  FIRST NATIONAL BANK OF GERMANT
# 3       2012    0000000182           1  EXCHANGE NATIONAL BANK & TRUST
# 4       2012    0000000324           1   FIRST NATIONAL BANK AND TRUST
#
#   Respondent_City_TS Respondent_State_TS Respondent_ZIP_Code  \
# 0        TERRE HAUTE                  IN               47802
# 1         CINCINNATI                  OH               45202
# 2         GERMANTOWN                  OH          45327-1349
# 3           ATCHISON                  KS               66002
# 4            NEWTOWN                  PA               18940
#
#                 Parent_Name_TS Parent_City_TS Parent_State_TS Parent_ZIP_Code  \
# 0  FIRST FINANCIAL CORPORATION    TERRE HAUTE              IN           47807
# 1                          NaN            NaN             NaN             NaN
# 2                          NaN            NaN             NaN             NaN
# 3                          NaN            NaN             NaN             NaN
# 4                          NaN            NaN             NaN             NaN
#
#    Assets_000_Panel
# 0           2854392
# 1           6663427
# 2             52094
# 3            330487
# 4            785017

# %%
Institutions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21655 entries, 0 to 21654
# Data columns (total 12 columns):
# As_of_Year             21655 non-null object
# Respondent_ID          21655 non-null object
# Agency_Code            21655 non-null object
# Respondent_Name_TS     21655 non-null object
# Respondent_City_TS     21655 non-null object
# Respondent_State_TS    21655 non-null object
# Respondent_ZIP_Code    21655 non-null object
# Parent_Name_TS         5458 non-null object
# Parent_City_TS         5455 non-null object
# Parent_State_TS        5486 non-null object
# Parent_ZIP_Code        5477 non-null object
# Assets_000_Panel       21655 non-null int64
# dtypes: int64(1), object(11)
# memory usage: 2.0+ MB

# %%
Loans.head()
# Out:
#   Agency_Code  Applicant_Income_000 As_of_Year Census_Tract_Number  \
# 0           3                  84.0       2012             0207.00
# 1           3                  84.0       2012             9556.00
# 2           3                  53.0       2012             9556.00
# 3           3                  85.0       2012             0206.01
# 4           3                  38.0       2012             0107.01
#
#   County_Code  FFIEC_Median_Family_Income  Loan_Amount_000 MSA_MD  \
# 0         079                     54900.0               94  16620
# 1         043                     54900.0              133  16620
# 2         043                     54900.0               70  16620
# 3         079                     54900.0              102  16620
# 4         039                     54900.0              112  16620
#
#   Number_of_Owner_Occupied_Units Respondent_ID             ...               \
# 0                       00001545    0000000384             ...
# 1                       00001548    0000000384             ...
# 2                       00001548    0000000384             ...
# 3                       00001935    0000000384             ...
# 4                       00001492    0000000384             ...
#
#   Loan_Purpose_Description Agency_Code_Description Lien_Status_Description  \
# 0                Refinance                    FDIC              First Lien
# 1                Refinance                    FDIC              First Lien
# 2                Refinance                    FDIC              First Lien
# 3                Refinance                    FDIC              First Lien
# 4                 Purchase                    FDIC              First Lien
#
#   Loan_Type_Description State County_Name Conforming_Limit_000  \
# 0          Conventional    WV      PUTNAM                417.0
# 1          Conventional    WV     LINCOLN                417.0
# 2          Conventional    WV     LINCOLN                417.0
# 3          Conventional    WV      PUTNAM                417.0
# 4          Conventional    WV     KANAWHA                417.0
#
#   Conventional_Status Conforming_Status Conventional_Conforming_Flag
# 0        Conventional        Conforming                            Y
# 1        Conventional        Conforming                            Y
# 2        Conventional        Conforming                            Y
# 3        Conventional        Conforming                            Y
# 4        Conventional        Conforming                            Y
#
# [5 rows x 24 columns]

# %%
Loans.describe()

# %%
Loans.info()

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Quality Assessment on Respondent_Name

# %%
#Institutions with Respondent_Name_TS issue
#In certain instances, for a particular respondent_id, every year the respondent seems to change. I have taken the most recent respondent name
NameIssue_Institutions = Institutions.groupby(['Respondent_ID','Agency_Code']).agg({'Respondent_Name_TS' : lambda x: len(pd.unique(x))}).reset_index()
NameIssue_Institutions = NameIssue_Institutions[NameIssue_Institutions['Respondent_Name_TS']!=1]

# %%
NameIssue_Institutions

# %%
#Let us look at an Example
Institutions[(Institutions['Respondent_ID']=='0000000395') & (Institutions['Agency_Code']=='5')]
# Out:
#       As_of_Year Respondent_ID Agency_Code              Respondent_Name_TS  \
# 4410        2012    0000000395           5         DAYTON FIREFIGHTERS FCU
# 11657       2013    0000000395           5  DAYTON FIREFIGHTERS FEDERAL CU
# 18739       2014    0000000395           5  DAYTON FIREFIGHTERS FEDERAL CR
#
#       Respondent_City_TS Respondent_State_TS Respondent_ZIP_Code  \
# 4410              DAYTON                  OH               45402
# 11657             DATYON                  OH               45402
# 18739             DAYTON                  OH               45402
#
#       Parent_Name_TS Parent_City_TS Parent_State_TS Parent_ZIP_Code  \
# 4410             NaN            NaN             NaN             NaN
# 11657            NaN            NaN             NaN             NaN
# 18739            NaN            NaN             NaN             NaN
#
#        Assets_000_Panel
# 4410              43068
# 11657             44530
# 18739             47779

# %% [markdown]
# ### Clean Institutions data

# %%
#Solution: Keep just the last record of Agency_Code, Respondent_ID
Clean_Institutions = Institutions.sort_values(by='As_of_Year')
Clean_Institutions = Clean_Institutions.drop_duplicates(subset = ['Agency_Code','Respondent_ID'], keep = 'last')

# %% [markdown]
# ### Clean Loans data

# %%
CleanLoans = Loans.copy()
Loans.head()
# Out:
#   Agency_Code  Applicant_Income_000 As_of_Year Census_Tract_Number  \
# 0           3                  84.0       2012             0207.00
# 1           3                  84.0       2012             9556.00
# 2           3                  53.0       2012             9556.00
# 3           3                  85.0       2012             0206.01
# 4           3                  38.0       2012             0107.01
#
#   County_Code  FFIEC_Median_Family_Income  Loan_Amount_000 MSA_MD  \
# 0         079                     54900.0               94  16620
# 1         043                     54900.0              133  16620
# 2         043                     54900.0               70  16620
# 3         079                     54900.0              102  16620
# 4         039                     54900.0              112  16620
#
#   Number_of_Owner_Occupied_Units Respondent_ID             ...               \
# 0                       00001545    0000000384             ...
# 1                       00001548    0000000384             ...
# 2                       00001548    0000000384             ...
# 3                       00001935    0000000384             ...
# 4                       00001492    0000000384             ...
#
#   Loan_Purpose_Description Agency_Code_Description Lien_Status_Description  \
# 0                Refinance                    FDIC              First Lien
# 1                Refinance                    FDIC              First Lien
# 2                Refinance                    FDIC              First Lien
# 3                Refinance                    FDIC              First Lien
# 4                 Purchase                    FDIC              First Lien
#
#   Loan_Type_Description State County_Name Conforming_Limit_000  \
# 0          Conventional    WV      PUTNAM                417.0
# 1          Conventional    WV     LINCOLN                417.0
# 2          Conventional    WV     LINCOLN                417.0
# 3          Conventional    WV      PUTNAM                417.0
# 4          Conventional    WV     KANAWHA                417.0
#
#   Conventional_Status Conforming_Status Conventional_Conforming_Flag
# 0        Conventional        Conforming                            Y
# 1        Conventional        Conforming                            Y
# 2        Conventional        Conforming                            Y
# 3        Conventional        Conforming                            Y
# 4        Conventional        Conforming                            Y
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Applicant_Income_000

# %%
#Fill Applicant fields with missing income (NULL and 0) with Family Income if available
CleanLoans.loc[CleanLoans['Applicant_Income_000'].isnull(),'Applicant_Income_000'] = CleanLoans.loc[CleanLoans['Applicant_Income_000'].isnull(),'FFIEC_Median_Family_Income']/1000
CleanLoans.loc[CleanLoans['Applicant_Income_000']==0,'Applicant_Income_000'] = CleanLoans.loc[CleanLoans['Applicant_Income_000']==0,'FFIEC_Median_Family_Income']/1000

# %%
#Drop Rows with no Applicant Income and No Family Income 
CleanLoans = CleanLoans[CleanLoans['Applicant_Income_000'].notnull()]

# %%
#Develop an Income Ratio Metric: Applicant_Family_IncomeRatio i.e. Check Ratio of Applicant Income to Median Family Income
#Drop rows where this Income Ratio is greater than 99 percentile (Another way could be to use a fixed value like 5 as a ceiling for this ratio)
CleanLoans['Applicant_Family_IncomeRatio'] = CleanLoans['Applicant_Income_000'] / (CleanLoans['FFIEC_Median_Family_Income']/1000)
CleanLoans['Applicant_Family_IncomeRatio'].describe()
# Out:
# count    1.319481e+06
# mean     1.319210e+00
# std      1.287710e+00
# min      8.984726e-03
# 25%      7.663198e-01
# 50%      1.018868e+00
# 75%      1.540616e+00
# max      1.637885e+02
# Name: Applicant_Family_IncomeRatio, dtype: float64

# %%
#Check Ratio Applicant Income, Median Family Income. 
CleanLoans['Applicant_Family_IncomeRatio'].quantile(np.arange(0,1,0.01))
# Out:
# 0.00    0.008985
# 0.01    0.273843
# 0.02    0.331126
# 0.03    0.370370
# 0.04    0.401494
# 0.05    0.428752
# 0.06    0.453258
# 0.07    0.473037
# 0.08    0.491958
# 0.09    0.512821
# 0.10    0.529801
# 0.11    0.549065
# 0.12    0.566572
# 0.13    0.582011
# 0.14    0.596026
# 0.15    0.613915
# 0.16    0.630841
# 0.17    0.644258
# 0.18    0.661376
# 0.19    0.677570
# 0.20    0.691114
# 0.21    0.708181
# 0.22    0.720588
# 0.23    0.736544
# 0.24    0.753968
# 0.25    0.766320
# 0.26    0.782710
# 0.27    0.795053
# 0.28    0.812379
# 0.29    0.829439
#           ...
# 0.70    1.409650
# 0.71    1.434109
# 0.72    1.460280
# 0.73    1.482890
# 0.74    1.510859
# 0.75    1.540616
# 0.76    1.568895
# 0.77    1.600467
# 0.78    1.634349
# 0.79    1.666667
# 0.80    1.702933
# 0.81    1.743397
# 0.82    1.783380
# 0.83    1.825095
# 0.84    1.869688
# 0.85    1.918195
# 0.86    1.974299
# 0.87    2.031030
# 0.88    2.091255
# 0.89    2.159686
# 0.90    2.233503
# 0.91    2.322887
# 0.92    2.414734
# 0.93    2.526636
# 0.94    2.661597
# 0.95    2.832861
# 0.96    3.055818
# 0.97    3.385703
# 0.98    3.947120
# 0.99    5.298159
# Name: Applicant_Family_IncomeRatio, dtype: float64

# %%
#Dropping rows where the IncomeRatio is greater than 99 percentile (Another way could be use a fixed value like 5)
CleanLoans = CleanLoans.drop(CleanLoans[CleanLoans['Applicant_Family_IncomeRatio']>CleanLoans['Applicant_Family_IncomeRatio'].quantile(0.99)].index)

# %%
CleanLoans.describe()
# Out:
#        Applicant_Income_000  FFIEC_Median_Family_Income  Loan_Amount_000  \
# count          1.294798e+06                1.293228e+06     1.294798e+06
# mean           1.054342e+02                8.770455e+04     2.831403e+02
# std            6.256328e+01                1.950725e+04     9.716624e+02
# min            1.000000e+00                4.530000e+04     1.000000e+00
# 25%            6.200000e+01                7.330000e+04     1.520000e+02
# 50%            9.000000e+01                8.560000e+04     2.320000e+02
# 75%            1.320000e+02                1.059000e+05     3.410000e+02
# max            1.519000e+03                1.134000e+05     9.962500e+04
#
#        Conforming_Limit_000  Applicant_Family_IncomeRatio
# count          1.294001e+06                  1.293228e+06
# mean           5.330116e+02                  1.206243e+00
# std            8.687892e+01                  6.516611e-01
# min            4.170000e+02                  8.984726e-03
# 25%            4.580000e+02                  7.593458e-01
# 50%            5.350000e+02                  1.001727e+00
# 75%            6.250000e+02                  1.495845e+00
# max            6.250000e+02                  3.955696e+00

# %%
#Check Ratio of Loan Amount and Applicant Income. New variable: Loan_Income_Ratio
CleanLoans['Loan_Income_Ratio'] = CleanLoans['Loan_Amount_000'] / CleanLoans['Applicant_Income_000']
CleanLoans['Loan_Income_Ratio'].describe()
# Out:
# count    1.294798e+06
# mean     3.457820e+00
# std      4.131678e+01
# min      3.937008e-03
# 25%      1.845133e+00
# 50%      2.618182e+00
# 75%      3.510000e+00
# max      5.997000e+03
# Name: Loan_Income_Ratio, dtype: float64

# %%
#Check Ratio Applicant Income, Loan Amount
CleanLoans['Loan_Income_Ratio'].quantile(np.arange(0,1,0.01))
# Out:
# 0.00    0.003937
# 0.01    0.343284
# 0.02    0.563107
# 0.03    0.708333
# 0.04    0.818926
# 0.05    0.909091
# 0.06    0.988764
# 0.07    1.058325
# 0.08    1.120879
# 0.09    1.180556
# 0.10    1.235294
# 0.11    1.285714
# 0.12    1.334586
# 0.13    1.383085
# 0.14    1.428571
# 0.15    1.470588
# 0.16    1.513043
# 0.17    1.553398
# 0.18    1.593301
# 0.19    1.630435
# 0.20    1.666667
# 0.21    1.704545
# 0.22    1.740654
# 0.23    1.776173
# 0.24    1.811321
# 0.25    1.845133
# 0.26    1.878205
# 0.27    1.910714
# 0.28    1.943182
# 0.29    1.975460
#           ...
# 0.70    3.300000
# 0.71    3.339130
# 0.72    3.380282
# 0.73    3.422897
# 0.74    3.466667
# 0.75    3.510000
# 0.76    3.555556
# 0.77    3.601434
# 0.78    3.650794
# 0.79    3.700000
# 0.80    3.750000
# 0.81    3.804348
# 0.82    3.860294
# 0.83    3.918699
# 0.84    3.978261
# 0.85    4.042857
# 0.86    4.111111
# 0.87    4.181818
# 0.88    4.259259
# 0.89    4.343720
# 0.90    4.431818
# 0.91    4.528302
# 0.92    4.633333
# 0.93    4.750000
# 0.94    4.884615
# 0.95    5.040000
# 0.96    5.227776
# 0.97    5.470595
# 0.98    5.826781
# 0.99    6.693130
# Name: Loan_Income_Ratio, dtype: float64

# %%
#Drop rows where the IncomeLoanRatio is greater than 99 percentile (Another way could be use a fixed value like 6)
CleanLoans = CleanLoans.drop(CleanLoans[CleanLoans['Loan_Income_Ratio']>CleanLoans['Loan_Income_Ratio'].quantile(0.99)].index)

# %%
#High amount Loans request are done by high income applicants (Probably not wrong data)
CleanLoans.sort_values(by='Loan_Amount_000', ascending=False).head(100)
# Out:
#         Agency_Code  Applicant_Income_000 As_of_Year Census_Tract_Number  \
# 1257320           2                 408.0       2014             9301.00
# 621583            9                 418.0       2013             0006.00
# 58136             9                 400.0       2012             0008.02
# 440023            9                 353.0       2012             4803.00
# 58496             9                 416.0       2012             0041.00
# 215000            7                 400.0       2012             7060.05
# 609204            5                 417.0       2013             0041.00
# 73413             7                 400.0       2012             0013.01
# 395525            5                 321.0       2012             4704.00
# 1137712           9                 359.0       2014             7055.02
# 74903             9                 400.0       2012             0006.00
# 611750            9                 312.0       2013             0001.00
# 56000             9                 390.0       2012             0002.02
# 1173265           7                1497.0       2014             NA
# 949394            9                 415.0       2013             2019.00
# 1069639           2                 371.0       2014             0001.00
# 611652            9                 383.0       2013             0041.00
# 915906            9                 389.0       2013             4701.00
# 719326            9                 392.0       2013             7060.09
# 1291724           3                 384.0       2014             4815.00
# 1290217           3                 369.0       2014             4801.00
# 986686            3                 406.0       2013             4709.00
# 163846            5                 311.0       2012             7059.03
# 711012            9                 397.0       2013             7060.08
# 206295            9                 355.0       2012             7059.01
# 610982            9                 395.0       2013             0001.00
# 704378            9                 415.0       2013             7047.00
# 1133049           9                 333.0       2014             7053.00
# 609251            5                 288.0       2013             0001.00
# 1134416           2                 313.0       2014             7055.02
# ...             ...                   ...        ...                 ...
# 454009            2                 397.0       2012             4156.00
# 937062            2                 361.0       2013             4801.00
# 716457            9                 404.0       2013             7060.08
# 1070114           9                 314.0       2014             0014.01
# 204065            9                 269.0       2012             7053.00
# 711652            9                 415.0       2013             7060.05
# 998437            7                 400.0       2013             1003.00
# 729851            9                 350.0       2013             7047.00
# 712630            2                 310.0       2013             7059.02
# 168048            9                 377.0       2012             7060.05
# 1271305           7                 325.0       2014             4804.02
# 492145            9                 389.0       2012             4803.00
# 700902            5                 416.0       2013             7060.08
# 1086670           9                 319.0       2014             7021.00
# 54780             5                 270.0       2012             0008.01
# 947368            9                 299.0       2013             4921.00
# 174047            9                 400.0       2012             7055.02
# 174413            9                 323.0       2012             7060.05
# 614655            9                 299.0       2013             0001.00
# 163666            5                 400.0       2012             7060.09
# 927381            2                 350.0       2013             4608.00
# 730360            9                 386.0       2013             7060.05
# 172854            9                 287.0       2012             7060.08
# 618037            2                 380.0       2013             0009.02
# 614644            9                 380.0       2013             0009.02
# 1252250           9                 298.0       2014             4703.00
# 141589            9                 257.0       2012             7011.01
# 166932            5                 326.0       2012             7055.02
# 976992            9                 337.0       2013             4802.01
# 908667            9                 356.0       2013             4802.01
#
#         County_Code  FFIEC_Median_Family_Income  Loan_Amount_000 MSA_MD  \
# 1257320         061                    107100.0             2315  47894
# 621583          001                    105900.0             2280  47894
# 58136           001                    105700.0             2274  47894
# 440023          059                    105700.0             2252  47894
# 58496           001                    105700.0             2250  47894
# 215000          031                    113400.0             2183  13644
# 609204          001                    105900.0             2158  47894
# 73413           001                    105700.0             2014  47894
# 395525          059                    105700.0             2000  47894
# 1137712         031                    111300.0             2000  43524
# 74903           001                    105700.0             2000  47894
# 611750          001                    105900.0             2000  47894
# 56000           001                    105700.0             2000  47894
# 1173265         031                         NaN             2000  NA
# 949394          510                    105900.0             2000  47894
# 1069639         001                    107100.0             2000  47894
# 611652          001                    105900.0             2000  47894
# 915906          059                    105900.0             2000  47894
# 719326          031                    112200.0             2000  13644
# 1291724         059                    107100.0             2000  47894
# 1290217         059                    107100.0             2000  47894
# 986686          059                    105900.0             2000  47894
# 163846          031                    113400.0             1999  13644
# 711012          031                    112200.0             1990  13644
# 206295          031                    113400.0             1961  13644
# 610982          001                    105900.0             1954  47894
# 704378          031                    112200.0             1935  13644
# 1133049         031                    111300.0             1920  43524
# 609251          001                    105900.0             1906  47894
# 1134416         031                    111300.0             1888  43524
# ...             ...                         ...              ...    ...
# 454009          059                    105700.0             1735  47894
# 937062          059                    105900.0             1733  47894
# 716457          031                    112200.0             1722  13644
# 1070114         001                    107100.0             1722  47894
# 204065          031                    113400.0             1721  13644
# 711652          031                    112200.0             1716  13644
# 998437          013                    105900.0             1715  47894
# 729851          031                    112200.0             1715  13644
# 712630          031                    112200.0             1714  13644
# 168048          031                    113400.0             1710  13644
# 1271305         059                    107100.0             1708  47894
# 492145          059                    105700.0             1700  47894
# 700902          031                    112200.0             1700  13644
# 1086670         003                     83500.0             1700  12580
# 54780           001                    105700.0             1700  47894
# 947368          059                    105900.0             1700  47894
# 174047          031                    113400.0             1700  13644
# 174413          031                    113400.0             1693  13644
# 614655          001                    105900.0             1693  47894
# 163666          031                    113400.0             1690  13644
# 927381          059                    105900.0             1685  47894
# 730360          031                    112200.0             1684  13644
# 172854          031                    113400.0             1680  13644
# 618037          001                    105900.0             1680  47894
# 614644          001                    105900.0             1680  47894
# 1252250         059                    107100.0             1680  47894
# 141589          003                     85600.0             1680  12580
# 166932          031                    113400.0             1676  13644
# 976992          059                    105900.0             1673  47894
# 908667          059                    105900.0             1672  47894
#
#         Number_of_Owner_Occupied_Units Respondent_ID        ...         \
# 1257320                       00001045    0000506922        ...
# 621583                        00001384    54-0259290        ...
# 58136                         00000841    0000451965        ...
# 440023                        00002167    0000675332        ...
# 58496                         00000713    0000476810        ...
# 215000                        00001349    7280100005        ...
# 609204                        00000713    0000005582        ...
# 73413                         00000570    7280100005        ...
# 395525                        00001488    0000005582        ...
# 1137712                       00001288    0002489805        ...
# 74903                         00001384    99-2933616        ...
# 611750                        00001296    0000451965        ...
# 56000                         00001142    0000413208        ...
# 1173265                       NA          7280100005        ...
# 949394                        00000404    0002735146        ...
# 1069639                       00001296    0002652092        ...
# 611652                        00000713    0000451965        ...
# 915906                        00000831    0000451965        ...
# 719326                        00001790    0002489805        ...
# 1291724                       00000726    54-2024584        ...
# 1290217                       00001292    54-2024584        ...
# 986686                        00002323    54-2024584        ...
# 163846                        00001422    0000005582        ...
# 711012                        00001678    0000480228        ...
# 206295                        00001329    54-0259290        ...
# 610982                        00001296    0000451965        ...
# 704378                        00001184    0000413208        ...
# 1133049                       00000643    0000480228        ...
# 609251                        00001296    0000005582        ...
# 1134416                       00001288    0000506922        ...
# ...                                ...           ...        ...
# 454009                        00000955    0001190074        ...
# 937062                        00001292    0000679826        ...
# 716457                        00001678    0000817824        ...
# 1070114                       00000760    0003212149        ...
# 204065                        00000643    54-0259290        ...
# 711652                        00001349    0000497404        ...
# 998437                        00001812    7280100005        ...
# 729851                        00001184    54-0259290        ...
# 712630                        00001288    0000506922        ...
# 168048                        00001349    0000413208        ...
# 1271305                       00001774    13-6131491        ...
# 492145                        00002167    54-0259290        ...
# 700902                        00001678    0000005582        ...
# 1086670                       00002165    0000480228        ...
# 54780                         00001852    0000005582        ...
# 947368                        00002036    0002489805        ...
# 174047                        00001288    0000476810        ...
# 174413                        00001349    0000476810        ...
# 614655                        00001296    0000504713        ...
# 163666                        00001790    0000005582        ...
# 927381                        00000829    0000506922        ...
# 730360                        00001349    54-0259290        ...
# 172854                        00001678    0000451965        ...
# 618037                        00000729    0002718345        ...
# 614644                        00000729    0000504713        ...
# 1252250                       00001037    0000451965        ...
# 141589                        00001377    54-0259290        ...
# 166932                        00001288    0000067955        ...
# 976992                        00001385    54-0259290        ...
# 908667                        00001385    0000451965        ...
#
#         Lien_Status_Description Loan_Type_Description State      County_Name  \
# 1257320              First Lien          Conventional    VA         FAUQUIER
# 621583               First Lien          Conventional    DC  DISTRICT OF COL
# 58136                First Lien          Conventional    DC  DISTRICT OF COL
# 440023               First Lien          Conventional    VA          FAIRFAX
# 58496                First Lien          Conventional    DC  DISTRICT OF COL
# 215000               First Lien          Conventional    MD       MONTGOMERY
# 609204               First Lien          Conventional    DC  DISTRICT OF COL
# 73413                First Lien          Conventional    DC  DISTRICT OF COL
# 395525               First Lien          Conventional    VA          FAIRFAX
# 1137712              First Lien          Conventional    MD       MONTGOMERY
# 74903                First Lien          Conventional    DC  DISTRICT OF COL
# 611750               First Lien          Conventional    DC  DISTRICT OF COL
# 56000                First Lien          Conventional    DC  DISTRICT OF COL
# 1173265              First Lien          Conventional    MD       MONTGOMERY
# 949394               First Lien          Conventional    VA       ALEXANDRIA
# 1069639              First Lien          Conventional    DC  DISTRICT OF COL
# 611652               First Lien          Conventional    DC  DISTRICT OF COL
# 915906               First Lien          Conventional    VA          FAIRFAX
# 719326               First Lien          Conventional    MD       MONTGOMERY
# 1291724              First Lien          Conventional    VA          FAIRFAX
# 1290217              First Lien          Conventional    VA          FAIRFAX
# 986686               First Lien          Conventional    VA          FAIRFAX
# 163846               First Lien          Conventional    MD       MONTGOMERY
# 711012               First Lien          Conventional    MD       MONTGOMERY
# 206295               First Lien          Conventional    MD       MONTGOMERY
# 610982               First Lien          Conventional    DC  DISTRICT OF COL
# 704378               First Lien          Conventional    MD       MONTGOMERY
# 1133049              First Lien          Conventional    MD       MONTGOMERY
# 609251               First Lien          Conventional    DC  DISTRICT OF COL
# 1134416              First Lien          Conventional    MD       MONTGOMERY
# ...                         ...                   ...   ...              ...
# 454009               First Lien          Conventional    VA          FAIRFAX
# 937062               First Lien          Conventional    VA          FAIRFAX
# 716457               First Lien          Conventional    MD       MONTGOMERY
# 1070114              First Lien          Conventional    DC  DISTRICT OF COL
# 204065               First Lien          Conventional    MD       MONTGOMERY
# 711652               First Lien          Conventional    MD       MONTGOMERY
# 998437               First Lien          Conventional    VA        ARLINGTON
# 729851               First Lien          Conventional    MD       MONTGOMERY
# 712630               First Lien          Conventional    MD       MONTGOMERY
# 168048               First Lien          Conventional    MD       MONTGOMERY
# 1271305              First Lien          Conventional    VA          FAIRFAX
# 492145               First Lien          Conventional    VA          FAIRFAX
# 700902               First Lien          Conventional    MD       MONTGOMERY
# 1086670              First Lien          Conventional    MD     ANNE ARUNDEL
# 54780                First Lien          Conventional    DC  DISTRICT OF COL
# 947368               First Lien          Conventional    VA          FAIRFAX
# 174047               First Lien          Conventional    MD       MONTGOMERY
# 174413               First Lien          Conventional    MD       MONTGOMERY
# 614655               First Lien          Conventional    DC  DISTRICT OF COL
# 163666               First Lien          Conventional    MD       MONTGOMERY
# 927381               First Lien          Conventional    VA          FAIRFAX
# 730360               First Lien          Conventional    MD       MONTGOMERY
# 172854               First Lien          Conventional    MD       MONTGOMERY
# 618037               First Lien          Conventional    DC  DISTRICT OF COL
# 614644               First Lien          Conventional    DC  DISTRICT OF COL
# 1252250              First Lien          Conventional    VA          FAIRFAX
# 141589               First Lien          Conventional    MD     ANNE ARUNDEL
# 166932               First Lien          Conventional    MD       MONTGOMERY
# 976992               First Lien          Conventional    VA          FAIRFAX
# 908667               First Lien          Conventional    VA          FAIRFAX
#
#         Conforming_Limit_000 Conventional_Status Conforming_Status  \
# 1257320                625.0        Conventional             Jumbo
# 621583                 625.0        Conventional             Jumbo
# 58136                  625.0        Conventional             Jumbo
# 440023                 625.0        Conventional             Jumbo
# 58496                  625.0        Conventional             Jumbo
# 215000                 625.0        Conventional             Jumbo
# 609204                 625.0        Conventional             Jumbo
# 73413                  625.0        Conventional             Jumbo
# 395525                 625.0        Conventional             Jumbo
# 1137712                625.0        Conventional             Jumbo
# 74903                  625.0        Conventional             Jumbo
# 611750                 625.0        Conventional             Jumbo
# 56000                  625.0        Conventional             Jumbo
# 1173265                625.0        Conventional             Jumbo
# 949394                 625.0        Conventional             Jumbo
# 1069639                625.0        Conventional             Jumbo
# 611652                 625.0        Conventional             Jumbo
# 915906                 625.0        Conventional             Jumbo
# 719326                 625.0        Conventional             Jumbo
# 1291724                625.0        Conventional             Jumbo
# 1290217                625.0        Conventional             Jumbo
# 986686                 625.0        Conventional             Jumbo
# 163846                 625.0        Conventional             Jumbo
# 711012                 625.0        Conventional             Jumbo
# 206295                 625.0        Conventional             Jumbo
# 610982                 625.0        Conventional             Jumbo
# 704378                 625.0        Conventional             Jumbo
# 1133049                625.0        Conventional             Jumbo
# 609251                 625.0        Conventional             Jumbo
# 1134416                625.0        Conventional             Jumbo
# ...                      ...                 ...               ...
# 454009                 625.0        Conventional             Jumbo
# 937062                 625.0        Conventional             Jumbo
# 716457                 625.0        Conventional             Jumbo
# 1070114                625.0        Conventional             Jumbo
# 204065                 625.0        Conventional             Jumbo
# 711652                 625.0        Conventional             Jumbo
# 998437                 625.0        Conventional             Jumbo
# 729851                 625.0        Conventional             Jumbo
# 712630                 625.0        Conventional             Jumbo
# 168048                 625.0        Conventional             Jumbo
# 1271305                625.0        Conventional             Jumbo
# 492145                 625.0        Conventional             Jumbo
# 700902                 625.0        Conventional             Jumbo
# 1086670                494.0        Conventional             Jumbo
# 54780                  625.0        Conventional             Jumbo
# 947368                 625.0        Conventional             Jumbo
# 174047                 625.0        Conventional             Jumbo
# 174413                 625.0        Conventional             Jumbo
# 614655                 625.0        Conventional             Jumbo
# 163666                 625.0        Conventional             Jumbo
# 927381                 625.0        Conventional             Jumbo
# 730360                 625.0        Conventional             Jumbo
# 172854                 625.0        Conventional             Jumbo
# 618037                 625.0        Conventional             Jumbo
# 614644                 625.0        Conventional             Jumbo
# 1252250                625.0        Conventional             Jumbo
# 141589                 494.0        Conventional             Jumbo
# 166932                 625.0        Conventional             Jumbo
# 976992                 625.0        Conventional             Jumbo
# 908667                 625.0        Conventional             Jumbo
#
#         Conventional_Conforming_Flag Applicant_Family_IncomeRatio  \
# 1257320                            N                     3.809524
# 621583                             N                     3.947120
# 58136                              N                     3.784295
# 440023                             N                     3.339640
# 58496                              N                     3.935667
# 215000                             N                     3.527337
# 609204                             N                     3.937677
# 73413                              N                     3.784295
# 395525                             N                     3.036897
# 1137712                            N                     3.225517
# 74903                              N                     3.784295
# 611750                             N                     2.946176
# 56000                              N                     3.689688
# 1173265                            N                          NaN
# 949394                             N                     3.918791
# 1069639                            N                     3.464052
# 611652                             N                     3.616619
# 915906                             N                     3.673277
# 719326                             N                     3.493761
# 1291724                            N                     3.585434
# 1290217                            N                     3.445378
# 986686                             N                     3.833805
# 163846                             N                     2.742504
# 711012                             N                     3.538324
# 206295                             N                     3.130511
# 610982                             N                     3.729934
# 704378                             N                     3.698752
# 1133049                            N                     2.991914
# 609251                             N                     2.719547
# 1134416                            N                     2.812219
# ...                              ...                          ...
# 454009                             N                     3.755913
# 937062                             N                     3.408876
# 716457                             N                     3.600713
# 1070114                            N                     2.931839
# 204065                             N                     2.372134
# 711652                             N                     3.698752
# 998437                             N                     3.777148
# 729851                             N                     3.119430
# 712630                             N                     2.762923
# 168048                             N                     3.324515
# 1271305                            N                     3.034547
# 492145                             N                     3.680227
# 700902                             N                     3.707665
# 1086670                            N                     3.820359
# 54780                              N                     2.554399
# 947368                             N                     2.823418
# 174047                             N                     3.527337
# 174413                             N                     2.848325
# 614655                             N                     2.823418
# 163666                             N                     3.527337
# 927381                             N                     3.305005
# 730360                             N                     3.440285
# 172854                             N                     2.530864
# 618037                             N                     3.588291
# 614644                             N                     3.588291
# 1252250                            N                     2.782446
# 141589                             N                     3.002336
# 166932                             N                     2.874780
# 976992                             N                     3.182247
# 908667                             N                     3.361662
#
#         Loan_Income_Ratio
# 1257320          5.674020
# 621583           5.454545
# 58136            5.685000
# 440023           6.379603
# 58496            5.408654
# 215000           5.457500
# 609204           5.175060
# 73413            5.035000
# 395525           6.230530
# 1137712          5.571031
# 74903            5.000000
# 611750           6.410256
# 56000            5.128205
# 1173265          1.336005
# 949394           4.819277
# 1069639          5.390836
# 611652           5.221932
# 915906           5.141388
# 719326           5.102041
# 1291724          5.208333
# 1290217          5.420054
# 986686           4.926108
# 163846           6.427653
# 711012           5.012594
# 206295           5.523944
# 610982           4.946835
# 704378           4.662651
# 1133049          5.765766
# 609251           6.618056
# 1134416          6.031949
# ...                   ...
# 454009           4.370277
# 937062           4.800554
# 716457           4.262376
# 1070114          5.484076
# 204065           6.397770
# 711652           4.134940
# 998437           4.287500
# 729851           4.900000
# 712630           5.529032
# 168048           4.535809
# 1271305          5.255385
# 492145           4.370180
# 700902           4.086538
# 1086670          5.329154
# 54780            6.296296
# 947368           5.685619
# 174047           4.250000
# 174413           5.241486
# 614655           5.662207
# 163666           4.225000
# 927381           4.814286
# 730360           4.362694
# 172854           5.853659
# 618037           4.421053
# 614644           4.421053
# 1252250          5.637584
# 141589           6.536965
# 166932           5.141104
# 976992           4.964392
# 908667           4.696629
#
# [100 rows x 26 columns]

# %% [markdown]
# ## Data Quality Check Summary
#
# ##### Institutions:
# **Respondent_Name** may vary from year to year so the safest option would be to keep one record as the true value. It can be either the oldest record or the newest record. For this we keep the oldest record
#
# ##### Loans
# **Applicant_Income_000, FFIEC_Median_Family_Income and Loan_Amount_000** are important to get a Loan so they need to be checked for quality.
#
# Some rules to clean the Loans data could be:
# * Fill *Applicant_Income* field null values with the *FFIEC_Median_Family_Income*.
# * Drop the records with *Applicant_Income* and *FFIEC_Median_Family_Income* fields both missing
# * Check the ratio between Applicant_Income_000 and FFIEC_Median_Family_Income. 99% of the records have a ratio lower than 5 so we can *remove all records where the ratio is greater than 5* which is a reasonable threshold
# * Check the ratio between Loan_Amount_000 and Applicant_Income_000. 99% of the records have a ratio lower than 6 so we could *remove all records where the ratio is greater than 6*

# %% [markdown]
# ## Data Munging

# %% [markdown]
# Merge the application data with institution data such that each loan application is assigned a Respondent_Name.
# Additionally, create a new attribute that buckets Loan_Amount_000 in reasonable groups

# %% [markdown]
# ### Plotting distribution to bucket Loans into reasonable groups

# %%
CleanLoans['Loan_Amount_000'].hist(bins=100)
plt.title("Loan Amount Histogram")
plt.xlabel("Amount in 1000's")
plt.ylabel("Frequency count")
fig = plt.gcf()
plt.show()

# %%
CleanLoans['Loan_Amount_000'].describe()
# Out:
# count    1.281850e+06
# mean     2.607742e+02
# std      1.552571e+02
# min      1.000000e+00
# 25%      1.520000e+02
# 50%      2.310000e+02
# 75%      3.400000e+02
# max      2.315000e+03
# Name: Loan_Amount_000, dtype: float64

# %%
LoanAmounts = np.array(CleanLoans['Loan_Amount_000'])
B1 = np.percentile(LoanAmounts, 40)
B2 = np.percentile(LoanAmounts, 80)
B3 = np.percentile(LoanAmounts, 95)

#Four practical buckets could be made using the values B1, B2, B3
#1,000 to 200,000 - Small
#200,000 to 400,000 - Medium
#400,000 to 600,000 - Big
#600,000 and above - Mega

# %%
def hmda_init(LoansDF, InstitutionsDF):
    
    #Clean Institutions
    #Keep just last record of Agency_Code, Respondent_ID
    Clean_Institutions = InstitutionsDF.sort_values(by='As_of_Year')
    Clean_Institutions = Clean_Institutions.drop_duplicates(subset = ['Agency_Code','Respondent_ID'], keep = 'last')
    
    #Clean Loans
    Clean_Loans = LoansDF.copy()
    #Fill NULL and 0 income with Family Income
    Clean_Loans.loc[Clean_Loans['Applicant_Income_000'].isnull(),'Applicant_Income_000'] = Clean_Loans.loc[Clean_Loans['Applicant_Income_000'].isnull(),'FFIEC_Median_Family_Income']/1000
    Clean_Loans.loc[Clean_Loans['Applicant_Income_000']==0,'Applicant_Income_000'] = Clean_Loans.loc[Clean_Loans['Applicant_Income_000']==0,'FFIEC_Median_Family_Income']/1000
    
    #Calculate Applicant/Family Income Ratio
    Clean_Loans['Applicant_Family_IncomeRatio'] = Clean_Loans['Applicant_Income_000'] / (Clean_Loans['FFIEC_Median_Family_Income']/1000)
    
    #Filter Applicant/Family Income Ratio Outliers
    Clean_Loans = Clean_Loans.drop(Clean_Loans[Clean_Loans['Applicant_Family_IncomeRatio']>5].index)
    
    #Calculate Loan Income Ratio
    Clean_Loans['Loan_Income_Ratio'] = Clean_Loans['Loan_Amount_000'] / Clean_Loans['Applicant_Income_000']
    
    #Filter Applicant/Family Income Ratio Outliers
    Clean_Loans = Clean_Loans.drop(Clean_Loans[Clean_Loans['Loan_Income_Ratio']>6].index)
    
    #Merge Application with Institutions
    MergedDF = Clean_Loans.merge(Clean_Institutions[['Agency_Code','Respondent_ID','Respondent_Name_TS']], how = 'inner', on = ['Agency_Code','Respondent_ID'])
    
    #Create buckets for Loan Amount looking at the distribution of the loan amounts
    MergedDF['Loan_Size'] = pd.cut(CleanLoans['Loan_Amount_000'],[min(CleanLoans['Loan_Amount_000']),200,400,600,max(CleanLoans['Loan_Amount_000'])], labels=['Small', 'Medium', 'Big', 'Mega'])
    
    #Drop Columns used for cleaning
    MergedDF = MergedDF.drop(['Applicant_Family_IncomeRatio','Loan_Income_Ratio'],axis = 1)
    
    return(MergedDF)

# %%
def hmda_to_json(data, output_path, states=None, conventional_conforming=None):
    FilteredData = data.copy()
    if states:
        FilteredData = FilteredData[FilteredData['State'].isin(states)]
    elif conventional_conforming:
        FilteredData = FilteredData[FilteredData['Conventional_Conforming_Flag']==conventional_conforming]
    FilteredData.to_json(output_path)
    print('File saved as: {}'.format(output_path))

# %%
ExpandedData = hmda_init(Loans, Institutions)

# %%
hmda_to_json(ExpandedData, 'test.json',['WV', 'DE'])
# Out:
# File saved as: test.json

# %% [markdown]
# #  Visualizations

# %% [markdown]
# ### Number of Loans per Year by State

# %%
ExpandedData.groupby(['State','As_of_Year'])['Loan_Amount_000'].count()
# Out:
# State  As_of_Year
# DC     2012           19583
#        2013           16530
#        2014           10768
# DE     2012           24577
#        2013           21870
#        2014           13643
# MD     2012          189719
#        2013          156179
#        2014           95041
# VA     2012          279938
#        2013          237272
#        2014          143941
# WV     2012           28123
#        2013           27696
#        2014           19641
# Name: Loan_Amount_000, dtype: int64

# %%
sns.countplot(x="State", hue="As_of_Year", data=ExpandedData, palette="Greens_d").set_title('Number of Loans per state across years')
plt.show()

# %% [markdown]
# ### Total Loan Amounts per Year by State

# %%
ExpandedData.groupby(['State','As_of_Year'])['Loan_Amount_000'].sum()
# Out:
# State  As_of_Year
# DC     2012           7464183
#        2013           6379529
#        2014           4502968
# DE     2012           5002625
#        2013           4361264
#        2014           2866401
# MD     2012          51479628
#        2013          41501868
#        2014          26864917
# VA     2012          74647218
#        2013          61949241
#        2014          39549022
# WV     2012           3873901
#        2013           3827546
#        2014           2720597
# Name: Loan_Amount_000, dtype: int64

# %%
ExpandedData.groupby(['State','As_of_Year'])['Loan_Amount_000'].sum().reset_index().pivot('State','As_of_Year','Loan_Amount_000').plot(kind='bar')
plt.title('Total Loan Amount per state across years')
plt.show()

# %% [markdown]
# **Both total number of Loans and total amount of loans are decreasing in all the states. Let's break it up by Purpose of Loan to see what is happening**

# %% [markdown]
# ### Number of Loans per Year per State by Purpose Description

# %%
ExpandedData.groupby(['State','Loan_Purpose_Description','As_of_Year'])['Loan_Amount_000'].count()
# Out:
# State  Loan_Purpose_Description  As_of_Year
# DC     Purchase                  2012            5599
#                                  2013            6234
#                                  2014            6501
#        Refinance                 2012           13984
#                                  2013           10296
#                                  2014            4267
# DE     Purchase                  2012            6992
#                                  2013            7687
#                                  2014            8105
#        Refinance                 2012           17585
#                                  2013           14183
#                                  2014            5538
# MD     Purchase                  2012           46135
#                                  2013           51861
#                                  2014           53613
#        Refinance                 2012          143584
#                                  2013          104318
#                                  2014           41428
# VA     Purchase                  2012           76024
#                                  2013           86045
#                                  2014           82313
#        Refinance                 2012          203914
#                                  2013          151227
#                                  2014           61628
# WV     Purchase                  2012            9906
#                                  2013           11085
#                                  2014           11274
#        Refinance                 2012           18217
#                                  2013           16611
#                                  2014            8367
# Name: Loan_Amount_000, dtype: int64

# %%
sns.factorplot(col="Loan_Purpose_Description", hue="As_of_Year",
               x="State", data=ExpandedData.sort_values(by='State'), kind="count", palette="Greens_d");
plt.show()

# %% [markdown]
# ### Loan Amount per Year per State by Purpose Description

# %%
ExpandedData.groupby(['State','Loan_Purpose_Description','As_of_Year'])['Loan_Amount_000'].sum()
# Out:
# State  Loan_Purpose_Description  As_of_Year
# DC     Purchase                  2012           2255402
#                                  2013           2658859
#                                  2014           2856127
#        Refinance                 2012           5208781
#                                  2013           3720670
#                                  2014           1646841
# DE     Purchase                  2012           1435130
#                                  2013           1648233
#                                  2014           1783575
#        Refinance                 2012           3567495
#                                  2013           2713031
#                                  2014           1082826
# MD     Purchase                  2012          13078382
#                                  2013          15394350
#                                  2014          16029090
#        Refinance                 2012          38401246
#                                  2013          26107518
#                                  2014          10835827
# VA     Purchase                  2012          20862574
#                                  2013          24750841
#                                  2014          23945089
#        Refinance                 2012          53784644
#                                  2013          37198400
#                                  2014          15603933
# WV     Purchase                  2012           1422336
#                                  2013           1663283
#                                  2014           1690377
#        Refinance                 2012           2451565
#                                  2013           2164263
#                                  2014           1030220
# Name: Loan_Amount_000, dtype: int64

# %%
TempDF = ExpandedData.groupby(['State','Loan_Purpose_Description','As_of_Year'])['Loan_Amount_000'].sum().reset_index()
TempDF = TempDF[TempDF['Loan_Purpose_Description']=='Purchase']
TempDF = TempDF.pivot('State','As_of_Year','Loan_Amount_000').plot(kind='bar')
plt.title('Total Value of Purchase Loans')
plt.show()


TempDF = ExpandedData.groupby(['State','Loan_Purpose_Description','As_of_Year'])['Loan_Amount_000'].sum().reset_index()
TempDF = TempDF[TempDF['Loan_Purpose_Description']=='Refinance']
TempDF = TempDF.pivot('State','As_of_Year','Loan_Amount_000').plot(kind='bar')
plt.title('Total Value of Refinance Loans')
plt.show()

# %% [markdown]
# **Refinance Loans are decreasing both in Total Value and Total Amount in all the states while Purchase Loans are growing in Value and Amount. Company may need to focus on Purchase loans**

# %% [markdown]
# #                                         # Choosing a market

# %%
ExpandedData.groupby(['State','Loan_Purpose_Description','As_of_Year']).median()
# Out:
#                                            Applicant_Income_000  \
# State Loan_Purpose_Description As_of_Year
# DC    Purchase                 2012                       121.0
#                                2013                       126.0
#                                2014                       130.0
#       Refinance                2012                       130.0
#                                2013                       122.0
#                                2014                       119.0
# DE    Purchase                 2012                        63.0
#                                2013                        67.0
#                                2014                        69.0
#       Refinance                2012                        81.9
#                                2013                        79.3
#                                2014                        78.8
# MD    Purchase                 2012                        85.6
#                                2013                        89.0
#                                2014                        90.0
#       Refinance                2012                       105.7
#                                2013                       100.0
#                                2014                        98.0
# VA    Purchase                 2012                        82.0
#                                2013                        85.0
#                                2014                        87.0
#       Refinance                2012                       103.0
#                                2013                        94.0
#                                2014                        90.0
# WV    Purchase                 2012                        59.0
#                                2013                        62.0
#                                2014                        62.0
#       Refinance                2012                        70.0
#                                2013                        67.0
#                                2014                        64.0
#
#                                            FFIEC_Median_Family_Income  \
# State Loan_Purpose_Description As_of_Year
# DC    Purchase                 2012                          105700.0
#                                2013                          105900.0
#                                2014                          107100.0
#       Refinance                2012                          105700.0
#                                2013                          105900.0
#                                2014                          107100.0
# DE    Purchase                 2012                           81900.0
#                                2013                           79300.0
#                                2014                           78800.0
#       Refinance                2012                           81900.0
#                                2013                           79300.0
#                                2014                           78800.0
# MD    Purchase                 2012                           85600.0
#                                2013                           85600.0
#                                2014                           83500.0
#       Refinance                2012                           85600.0
#                                2013                           85600.0
#                                2014                           83500.0
# VA    Purchase                 2012                           75600.0
#                                2013                           73900.0
#                                2014                           76400.0
#       Refinance                2012                          105700.0
#                                2013                           73900.0
#                                2014                           76400.0
# WV    Purchase                 2012                           53200.0
#                                2013                           57400.0
#                                2014                           54600.0
#       Refinance                2012                           53200.0
#                                2013                           57400.0
#                                2014                           52700.0
#
#                                            Loan_Amount_000  \
# State Loan_Purpose_Description As_of_Year
# DC    Purchase                 2012                    369
#                                2013                    392
#                                2014                    404
#       Refinance                2012                    346
#                                2013                    324
#                                2014                    343
# DE    Purchase                 2012                    191
#                                2013                    201
#                                2014                    206
#       Refinance                2012                    190
#                                2013                    180
#                                2014                    180
# MD    Purchase                 2012                    253
#                                2013                    265
#                                2014                    268
#       Refinance                2012                    248
#                                2013                    225
#                                2014                    230
# VA    Purchase                 2012                    240
#                                2013                    252
#                                2014                    253
#       Refinance                2012                    240
#                                2013                    216
#                                2014                    216
# WV    Purchase                 2012                    130
#                                2013                    136
#                                2014                    134
#       Refinance                2012                    119
#                                2013                    113
#                                2014                    106
#
#                                            Conforming_Limit_000
# State Loan_Purpose_Description As_of_Year
# DC    Purchase                 2012                       625.0
#                                2013                       625.0
#                                2014                       625.0
#       Refinance                2012                       625.0
#                                2013                       625.0
#                                2014                       625.0
# DE    Purchase                 2012                       417.0
#                                2013                       417.0
#                                2014                       417.0
#       Refinance                2012                       417.0
#                                2013                       417.0
#                                2014                       417.0
# MD    Purchase                 2012                       494.0
#                                2013                       494.0
#                                2014                       494.0
#       Refinance                2012                       494.0
#                                2013                       494.0
#                                2014                       494.0
# VA    Purchase                 2012                       535.0
#                                2013                       535.0
#                                2014                       535.0
#       Refinance                2012                       625.0
#                                2013                       535.0
#                                2014                       535.0
# WV    Purchase                 2012                       417.0
#                                2013                       417.0
#                                2014                       417.0
#       Refinance                2012                       417.0
#                                2013                       417.0
#                                2014                       417.0

# %%
TempDF = ExpandedData.groupby(['State','Loan_Purpose_Description','As_of_Year'])['Loan_Amount_000'].median().reset_index()
TempDF = TempDF[TempDF['Loan_Purpose_Description']=='Purchase']
TempDF = TempDF.pivot('State','As_of_Year','Loan_Amount_000').plot(kind='bar')
plt.title('Median Value of Purchase Loans')
plt.show()

# %% [markdown]
# **My recommendation would be to Focus on MD and VA because they have the highest number of Loans and highest loan amounts.
# However DC area is something that shouldn't be overlooked because the median value of Purchase Loans is the highest in that State**

# %% [markdown]
# ## One Step Further

# %% [markdown]
# Let us go deeper into geographies and cluster different counties based on lending patterns

# %%
ExpandedData.columns
# Out:
# Index(['Agency_Code', 'Applicant_Income_000', 'As_of_Year',
#        'Census_Tract_Number', 'County_Code', 'FFIEC_Median_Family_Income',
#        'Loan_Amount_000', 'MSA_MD', 'Number_of_Owner_Occupied_Units',
#        'Respondent_ID', 'Sequence_Number', 'State_Code',
#        'Tract_to_MSA_MD_Income_Pct', 'MSA_MD_Description',
#        'Loan_Purpose_Description', 'Agency_Code_Description',
#        'Lien_Status_Description', 'Loan_Type_Description', 'State',
#        'County_Name', 'Conforming_Limit_000', 'Conventional_Status',
#        'Conforming_Status', 'Conventional_Conforming_Flag',
#        'Respondent_Name_TS', 'Loan_Size'],
#       dtype='object')

# %%
ClusterData = ExpandedData[['Applicant_Income_000', 'Loan_Amount_000', 
       'Loan_Purpose_Description', 'Lien_Status_Description', 'State',
       'County_Name', 'Conforming_Limit_000', 'Conventional_Status',
       'Conforming_Status', 'Respondent_Name_TS','Conventional_Conforming_Flag']]

# %%
ClusterData.isnull().sum()/len(ClusterData)
# Out:
# Applicant_Income_000            0.000083
# Loan_Amount_000                 0.000000
# Loan_Purpose_Description        0.000000
# Lien_Status_Description         0.000000
# State                           0.000000
# County_Name                     0.000649
# Conforming_Limit_000            0.000649
# Conventional_Status             0.000000
# Conforming_Status               0.000000
# Respondent_Name_TS              0.000000
# Conventional_Conforming_Flag    0.000000
# dtype: float64

# %%
#As Percentage of Nulls is low we can safely drop them 
ClusterData = ClusterData.dropna()

# %%
#Create Dummies for Categorical Variables
ClusterData = pd.get_dummies(ClusterData, columns = ['Loan_Purpose_Description','Lien_Status_Description','Conventional_Status','Conforming_Status','Conventional_Conforming_Flag'])

# %%
ClusterData['No_Loans'] = 1

# %%
ClusterData.columns
# Out:
# Index(['Applicant_Income_000', 'Loan_Amount_000', 'State', 'County_Name',
#        'Conforming_Limit_000', 'Respondent_Name_TS',
#        'Loan_Purpose_Description_Purchase',
#        'Loan_Purpose_Description_Refinance',
#        'Lien_Status_Description_First Lien',
#        'Lien_Status_Description_Subordinate Lien',
#        'Conventional_Status_Conventional',
#        'Conventional_Status_Non-Conventional', 'Conforming_Status_Conforming',
#        'Conforming_Status_Jumbo', 'Conventional_Conforming_Flag_N',
#        'Conventional_Conforming_Flag_Y', 'No_Loans'],
#       dtype='object')

# %% [markdown]
#  ### Cluster by County

# %%
CountyData = ClusterData.groupby(['County_Name']).agg({'Applicant_Income_000': 'median', 
                                          'Loan_Amount_000': 'median', 
                                          'No_Loans':'sum',
                                          'Loan_Purpose_Description_Purchase':'sum' ,
                                          'Lien_Status_Description_First Lien': 'sum', 
                                          'Conforming_Limit_000': 'median', 
                                          'Conventional_Status_Conventional' : 'sum',
                                          'Conforming_Status_Conforming': 'sum', 
                                          'Conventional_Conforming_Flag_Y' : 'sum'})

# %%
#Convert Categorical Columns to Percentage
for column in ['Loan_Purpose_Description_Purchase','Lien_Status_Description_First Lien','Conventional_Status_Conventional',
              'Conforming_Status_Conforming','Conventional_Conforming_Flag_Y']:
    CountyData[column] = CountyData[column]/ CountyData['No_Loans']

# %% [markdown]
# #Drop No of Obs CountyData = CountyData.drop('No_Obs', axis = 1)

# %%
CountyData.head()
# Out:
#              Conforming_Limit_000  Conventional_Status_Conventional  \
# County_Name
# ACCOMACK                    417.0                          0.750727
# ALBEMARLE                   437.0                          0.834753
# ALEXANDRIA                  625.0                          0.810613
# ALLEGANY                    417.0                          0.738364
# ALLEGHANY                   417.0                          0.641248
#
#              Conforming_Status_Conforming  Applicant_Income_000  \
# County_Name
# ACCOMACK                         0.988361                  65.0
# ALBEMARLE                        0.936698                  93.0
# ALEXANDRIA                       0.895501                 133.0
# ALLEGANY                         0.999335                  56.0
# ALLEGHANY                        1.000000                  57.0
#
#              Loan_Amount_000  Conventional_Conforming_Flag_Y  \
# County_Name
# ACCOMACK               141.0                        0.740058
# ALBEMARLE              241.0                        0.779204
# ALEXANDRIA             368.0                        0.735428
# ALLEGANY                94.5                        0.737699
# ALLEGHANY              107.0                        0.641248
#
#              Lien_Status_Description_First Lien  \
# County_Name
# ACCOMACK                               0.981571
# ALBEMARLE                              0.987162
# ALEXANDRIA                             0.983036
# ALLEGANY                               0.961436
# ALLEGHANY                              0.991334
#
#              Loan_Purpose_Description_Purchase  No_Loans
# County_Name
# ACCOMACK                              0.317168      1031
# ALBEMARLE                             0.393416      7867
# ALEXANDRIA                            0.407071     14737
# ALLEGANY                              0.339096      3008
# ALLEGHANY                             0.421144       577

# %%
#Normalize data to mean 0 and variance 1 for clustering
scaler = StandardScaler()
scaler.fit(CountyData)
CountyDataScaled = scaler.transform(CountyData)

# %%
#Loop to find the optimal number of clusters
Inertia = [None,None] #None because we are not calculating inertia for cluster = 0 or cluster = 1
for clusternumber in range(2,100,1):
    model = KMeans(n_clusters= clusternumber)
    model.fit(CountyDataScaled)
    Inertia.append(model.inertia_)

# %%
#Elbow method to choose the optimal number of clusters
plt.title('Inertia - Number of Clusters Trade off')
plt.plot(Inertia)
plt.show()

# %% [markdown]
# Looks like 10 cluster is the optimal number of clusters

# %%
#Run K means for number of clusters = 10
model = KMeans(n_clusters= 10)
model.fit(CountyDataScaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
#Get Cluster Results
CountyData['Cluster'] = model.labels_

# %%
#Get Centroids to understand Clusters
CountyClusterResults = CountyData.groupby('Cluster').mean()

#Add Number of Counties per Cluster
CountyClusterResults['No_Counties'] = CountyData.groupby('Cluster')['Loan_Amount_000'].count()

# %%
#Sort Clusters by Percentage of Purchase Loans
CountyClusterResults.sort_values(by = 'Loan_Purpose_Description_Purchase', ascending=False)
# Out:
#          Conforming_Limit_000  Conventional_Status_Conventional  \
# Cluster
# 2                  417.571429                          0.769063
# 6                  496.500000                          0.482837
# 4                  625.000000                          0.602312
# 9                  425.128205                          0.635210
# 8                  581.333333                          0.667672
# 7                  417.000000                          0.741680
# 5                  603.166667                          0.859864
# 1                  477.592593                          0.704575
# 0                  625.000000                          0.839630
# 3                  418.285714                          0.805847
#
#          Conforming_Status_Conforming  Applicant_Income_000  Loan_Amount_000  \
# Cluster
# 2                            0.996127             61.740000       105.528571
# 6                            0.993926             68.868750       164.500000
# 4                            0.993207             96.227273       239.454545
# 9                            0.996190             60.061538       136.000000
# 8                            0.971393            100.050000       262.333333
# 7                            0.995652             59.469697       118.727273
# 5                            0.882714            134.166667       365.166667
# 1                            0.974658             81.522222       209.703704
# 0                            0.924061            124.000000       332.500000
# 3                            0.992172             60.677143       124.942857
#
#          Conventional_Conforming_Flag_Y  Lien_Status_Description_First Lien  \
# Cluster
# 2                              0.765765                            0.988662
# 6                              0.479287                            0.972782
# 4                              0.598713                            0.987208
# 9                              0.632476                            0.989582
# 8                              0.649536                            0.989359
# 7                              0.737876                            0.971701
# 5                              0.763602                            0.986167
# 1                              0.684947                            0.982846
# 0                              0.777289                            0.987016
# 3                              0.799490                            0.986144
#
#          Loan_Purpose_Description_Purchase       No_Loans  No_Counties
# Cluster
# 2                                 0.447908    1317.371429           35
# 6                                 0.382472    7618.687500           16
# 4                                 0.376261    6971.818182           11
# 9                                 0.374794    1843.076923           39
# 8                                 0.370375   48681.666667            6
# 7                                 0.369900    1869.212121           33
# 5                                 0.359419   19879.500000            6
# 1                                 0.352702    9268.777778           27
# 0                                 0.304046  109691.500000            2
# 3                                 0.296277     695.771429           35

# %% [markdown]
# **Change Financial should be focusing on Clusters 8, 4 and 9**
#
# **Counties in Cluster 8 have a low average number of loans but contains the highest percentage of Purchase Loans. Also, the number of counties in this cluster is high making it potentially a good market**
#
# **Cluster 4 has the second highest percentage of Purchase loans (Growing Segment). Also the counties in this cluster have a high average number of loans, so the market size is big eventhough the number of counties in this cluster is low**
#
# **Cluster 9 is another good market because it too contains a high average number of loans and the percentage of Purchase loans is not too different from cluster 4**

# %%
#Counties in CLuster 8
CountyData[CountyData['Cluster']==8].index
# Out:
# Index(['ANNE ARUNDEL', 'BALTIMORE', 'FREDERICK', 'LOUDOUN', 'PRINCE GEORGE'S',
#        'PRINCE WILLIAM'],
#       dtype='object', name='County_Name')

# %%
#Counties in CLuster 4
CountyData[CountyData['Cluster']==4].index
# Out:
# Index(['CALVERT', 'CHARLES', 'CLARKE', 'FAUQUIER', 'FREDERICKSBURG',
#        'JEFFERSON', 'MANASSAS', 'MANASSAS PARK', 'SPOTSYLVANIA', 'STAFFORD',
#        'WARREN'],
#       dtype='object', name='County_Name')

# %%
#Counties in CLuster 9
CountyData[CountyData['Cluster']==9].index
# Out:
# Index(['ALLEGHANY', 'AMELIA', 'AMHERST', 'APPOMATTOX', 'BARBOUR',
#        'BEDFORD IND', 'BERKELEY', 'BUCKINGHAM', 'CAMPBELL', 'COVINGTON',
#        'CULPEPER', 'DANVILLE', 'DORCHESTER', 'EMPORIA', 'ESSEX', 'FLUVANNA',
#        'FRANKLIN IND', 'GALAX', 'GREENE', 'HENRY', 'KENT', 'KING AND QUEEN',
#        'MARTINSVILLE', 'MONROE', 'NOTTOWAY', 'ORANGE', 'PITTSYLVANIA',
#        'PRINCE EDWARD', 'PULASKI', 'RADFORD', 'RANDOLPH', 'SHENANDOAH',
#        'SOMERSET', 'SOUTHAMPTON', 'SURRY', 'TAZEWELL', 'WASHINGTON',
#        'WESTMORELAND', 'WICOMICO'],
#       dtype='object', name='County_Name')

# %% [markdown]
# # Some Interactivity

# %%
'''The following function displays the major players in the home loans market in a chosen state 
The function takes in the state name(For ex: 'MD'), Top_n as the number of top banks, and the dataset(ExpandedData) as parameters'''

def TopNBanks(State, N, ExpandedData):
    df1 = ExpandedData[ExpandedData.As_of_Year == '2014']
    df2 =df1[df1['State']==State] 
    df3 = df2[['Loan_Amount_000', 'Respondent_Name_TS']].groupby('Respondent_Name_TS').sum()
    df4 = df3['Loan_Amount_000']
    data = {'Respondent_Name_TS':df4.index.values, 'Loan_Amount_000':df4.values} 
    df5 = pd.DataFrame(data).nlargest(N, 'Loan_Amount_000')
    labels = df5['Respondent_Name_TS']
    Data = df5['Loan_Amount_000']
    fig1, ax1 = plt.subplots()
    ax1.pie(Data, labels=labels, autopct='%1.1f%%',
    shadow=True, startangle=90)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %%
#Example: Let us see who the top 10 players are in Virginia, in terms of total Loan Amount
TopNBanks('VA', 10, ExpandedData)

# %%
'''The following function displays market share for a competitor in a chosen geography(state). 
The function takes in the company name as a string, State(s) as a **list** (For ex: ['VA', 'DC'], and the dataset as parameters'''

def MarketShare (CompanyName, Geography, ExpandedData):
    ExpandedData2014_df = ExpandedData[ExpandedData.As_of_Year == '2014']
    TempDF1 =ExpandedData2014_df[ExpandedData2014_df.State.isin(Geography)]
    TempDF2 = TempDF1[TempDF1['Respondent_Name_TS'] == CompanyName]
    TotalGeographySales = TempDF1['Loan_Amount_000'].sum()
    TotalCompanySales = TempDF2['Loan_Amount_000'].sum()
    CompanyMarketShare = TotalCompanySales  / TotalGeographySales 
    OthersMarketShare = 1 - CompanyMarketShare
    
    labels = [CompanyName, 'Rest of the Competitors']
    Data = [CompanyMarketShare , OthersMarketShare]
    explode = (0.1, 0)
    fig1, ax1 = plt.subplots()
    ax1.pie(Data, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
    ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# %%
#Example: Let us see what the combined market share of MCLEAN MORTGAGE CORPORATION is in the states fo VA, DE, MD 
MarketShare('MCLEAN MORTGAGE CORPORATION', ['VA', 'DE','MD'], ExpandedData)

# %% [markdown]
# # SUMMARY
#
# **1.**	When we break down the loans in terms of purpose, we see that refinancing loans makes up the largest share of the two in terms of amount. Also, existing lenders seem to sanction refinancing loans more than new home purchase loans.
#
# **2.**	However, refinance Loans are decreasing both in Total Value across the years and Total number in all the states while Purchase Loans are growing in Value and Amount of loans.
#
# **3.**	My recommendation would be to focus on MD and VA because they have the highest number of Loans and highest loan amounts. However, the DC area is something that shouldn't be overlooked because the median value of Purchase Loans is the highest there
#
# **4.**	However, although there is a decreasing trend in refinance loans, banks still prefer refinance loans more. Hence it would be unwise not to target refinance loans especially in the big geographies such as VA, MD
#
# **5.**	Due to large number of loan applications and relatively high applicant income - its ideal for Change Financial to consider both Maryland or Virginia states.
#
# **6.**	Also, looking at the clusters of similar counties, as explained in the code, I would recommend Change Financial target especially these clusters of counties (**8, 4 and 9**) with intensive marketing and outreach activities.
#
# *Cluster 8 has a low average number of loans but contains the highest percentage of Purchase Loans. Also, the number of counties in this cluster is high making it potentially a good market. Cluster 4 has the second highest percentage of Purchase loans (Growing Segment). Also the counties in this cluster have a high average number of loans, so the market size is big even though the number of counties in this cluster is low. Cluster 9 is another good market because it too contains a high average number of loans and the percentage of Purchase loans is not too different from cluster 4*
#
# **7.**	More needs to be done to explore if the general decline in volume and amount of loans in these 5 states is also seen in the rest of the country and the reasons examined therein.
